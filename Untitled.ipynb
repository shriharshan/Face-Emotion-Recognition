# %%
import tensorflow as tf

# %%
train_dir = "train"
test_dir = "test"

# %%
dataGenerator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, horizontal_flip=True, validation_split=0.2)

training_data = dataGenerator.flow_from_directory(train_dir, batch_size=64, target_size=(48, 48), shuffle=True, color_mode='grayscale', class_mode='categorical', subset='training')
validation_set = dataGenerator.flow_from_directory(train_dir, batch_size=64, target_size=(48, 48), shuffle=True, color_mode='grayscale', class_mode='categorical', subset='validation')

testDataGenerator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, horizontal_flip=True)

test_data = testDataGenerator.flow_from_directory(test_dir, batch_size=64, target_size=(48, 48), shuffle=True, color_mode='grayscale', class_mode='categorical')
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
def create_model():
    weight_decay = 1e-4
    model = tf.keras.models.Sequential()

    model.add(tf.keras.layers.Conv2D(64, (4, 4), padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(48, 48, 1)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(64, (4, 4), padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.2))

    model.add(tf.keras.layers.Conv2D(128, (4, 4), padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.3))
    
    model.add(tf.keras.layers.Conv2D(128, (4, 4), padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2D(128, (4, 4), padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay)))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation="linear"))
    model.add(tf.keras.layers.Activation('relu'))
    model.add(tf.keras.layers.Dense(7, activation='softmax'))
    
    return model

# %%
model = create_model()

model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(0.0003), metrics=['accuracy'])

# %%
checkpointer = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', verbose = 1, restore_best_weights=True, mode="max",patience = 10),
                tf.keras.callbacks.ModelCheckpoint(
                    filepath='final_model_weights.hdf5',
                    monitor="val_accuracy",
                    verbose=1,
                    save_best_only=True,
                    mode="max")]

# %%
steps_per_epoch = training_data.n // training_data.batch_size
validation_steps = validation_set.n // validation_set.batch_size

history = model.fit(x=training_data,
                validation_data=validation_set,
                epochs=100,
                callbacks=[checkpointer],
                steps_per_epoch=steps_per_epoch,
                validation_steps=validation_steps)
# Out:
# Epoch 1/100
# 358/358 [==============================] - ETA: 0s - loss: 1.8302 - accuracy: 0.3115
# Epoch 1: val_accuracy improved from -inf to 0.17907, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 545s 2s/step - loss: 1.8302 - accuracy: 0.3115 - val_loss: 2.1083 - val_accuracy: 0.1791
# Epoch 2/100
# 358/358 [==============================] - ETA: 0s - loss: 1.5417 - accuracy: 0.4182
# Epoch 2: val_accuracy improved from 0.17907 to 0.42995, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 418s 1s/step - loss: 1.5417 - accuracy: 0.4182 - val_loss: 1.5414 - val_accuracy: 0.4300
# Epoch 3/100
# 358/358 [==============================] - ETA: 0s - loss: 1.4128 - accuracy: 0.4720
# Epoch 3: val_accuracy improved from 0.42995 to 0.48420, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 423s 1s/step - loss: 1.4128 - accuracy: 0.4720 - val_loss: 1.3933 - val_accuracy: 0.4842
# Epoch 4/100
# 358/358 [==============================] - ETA: 0s - loss: 1.3195 - accuracy: 0.5119
# Epoch 4: val_accuracy improved from 0.48420 to 0.52721, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 412s 1s/step - loss: 1.3195 - accuracy: 0.5119 - val_loss: 1.2717 - val_accuracy: 0.5272
# Epoch 5/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2581 - accuracy: 0.5391
# Epoch 5: val_accuracy did not improve from 0.52721
# 358/358 [==============================] - 396s 1s/step - loss: 1.2581 - accuracy: 0.5391 - val_loss: 1.3028 - val_accuracy: 0.5212
# Epoch 6/100
# 358/358 [==============================] - ETA: 0s - loss: 1.2109 - accuracy: 0.5568
# Epoch 6: val_accuracy improved from 0.52721 to 0.54723, saving model to final_model_weights.hdf5
# 358/358 [==============================] -
saving model to final_model_weights.hdf5
# 358/358 [==============================] - 392s 1s/step - loss: 0.6483 - accuracy: 0.7956 - val_loss: 1.2476 - val_accuracy: 0.6331
# Epoch 31/100
# 358/358 [==============================] - ETA: 0s - loss: 0.6328 - accuracy: 0.8028
# Epoch 31: val_accuracy did not improve from 0.63308
# 358/358 [==============================] - 399s 1s/step - loss: 0.6328 - accuracy: 0.8028 - val_loss: 1.2663 - val_accuracy: 0.6234
# Epoch 32/100
# 358/358 [==============================] - ETA: 0s - loss: 0.6182 - accuracy: 0.8039
# Epoch 32: val_accuracy did not improve from 0.63308
# 358/358 [==============================] - 408s 1s/step - loss: 0.6182 - accuracy: 0.8039 - val_loss: 1.2817 - val_accuracy: 0.6289
# Epoch 33/100
# 358/358 [==============================] - ETA: 0s - loss: 0.6084 - accuracy: 0.8108
# Epoch 33: val_accuracy did not improve from 0.63308
# 358/358 [==============================] - 399s 1s/step - loss: 0.6084 - accuracy: 0.8108 - val_loss: 1.2845 - val_accuracy: 0.6261
# Epoch 34/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5881 - accuracy: 0.8206
# Epoch 34: val_accuracy improved from 0.63308 to 0.63395, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 395s 1s/step - loss: 0.5881 - accuracy: 0.8206 - val_loss: 1.3029 - val_accuracy: 0.6340
# Epoch 35/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5796 - accuracy: 0.8233
# Epoch 35: val_accuracy did not improve from 0.63395
# 358/358 [==============================] - 393s 1s/step - loss: 0.5796 - accuracy: 0.8233 - val_loss: 1.3007 - val_accuracy: 0.6324
# Epoch 36/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5672 - accuracy: 0.8278
# Epoch 36: val_accuracy did not improve from 0.63395
# 358/358 [==============================] - 407s 1s/step - loss: 0.5672 - accuracy: 0.8278 - val_loss: 1.3299 - val_accuracy: 0.6239
# Epoch 37/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5612 - accuracy: 0.8301
# Epoch 37: val_accuracy did not improve from 0.63395
# 358/358 [==============================] - 389s 1s/step - loss: 0.5612 - accuracy: 0.8301 - val_loss: 1.3291 - val_accuracy: 0.6301
# Epoch 38/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5453 - accuracy: 0.8339
# Epoch 38: val_accuracy did not improve from 0.63395
# 358/358 [==============================] - 398s 1s/step - loss: 0.5453 - accuracy: 0.8339 - val_loss: 1.3468 - val_accuracy: 0.6317
# Epoch 39/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5351 - accuracy: 0.8430
# Epoch 39: val_accuracy did not improve from 0.63395
# 358/358 [==============================] - 376s 1s/step - loss: 0.5351 - accuracy: 0.8430 - val_loss: 1.3855 - val_accuracy: 0.6304
# Epoch 40/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.8463
# Epoch 40: val_accuracy did not improve from 0.63395
# 358/358 [==============================] - 377s 1s/step - loss: 0.5197 - accuracy: 0.8463 - val_loss: 1.3933 - val_accuracy: 0.6285
# Epoch 41/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5229 - accuracy: 0.8481
# Epoch 41: val_accuracy improved from 0.63395 to 0.63957, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 376s 1s/step - loss: 0.5229 - accuracy: 0.8481 - val_loss: 1.3734 - val_accuracy: 0.6396
# Epoch 42/100
# 358/358 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.8530
# Epoch 42: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 374s 1s/step - loss: 0.5073 - accuracy: 0.8530 - val_loss: 1.4220 - val_accuracy: 0.6364
# Epoch 43/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.8548
# Epoch 43: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 377s 1s/step - loss: 0.4987 - accuracy: 0.8548 - val_loss: 1.3828 - val_accuracy: 0.6355
# Epoch 44/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.8578
# Epoch 44: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 374s 1s/step - loss: 0.4897 - accuracy: 0.8578 - val_loss: 1.4654 - val_accuracy: 0.6308
# Epoch 45/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.8595
# Epoch 45: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 378s 1s/step - loss: 0.4859 - accuracy: 0.8595 - val_loss: 1.4198 - val_accuracy: 0.6376
# Epoch 46/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.8658
# Epoch 46: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 378s 1s/step - loss: 0.4816 - accuracy: 0.8658 - val_loss: 1.4548 - val_accuracy: 0.6336
# Epoch 47/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.8706
# Epoch 47: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 379s 1s/step - loss: 0.4679 - accuracy: 0.8706 - val_loss: 1.4674 - val_accuracy: 0.6394
# Epoch 48/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4630 - accuracy: 0.8711
# Epoch 48: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 384s 1s/step - loss: 0.4630 - accuracy: 0.8711 - val_loss: 1.4823 - val_accuracy: 0.6329
# Epoch 49/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4594 - accuracy: 0.8730
# Epoch 49: val_accuracy did not improve from 0.63957
# 358/358 [==============================] - 379s 1s/step - loss: 0.4594 - accuracy: 0.8730 - val_loss: 1.5225 - val_accuracy: 0.6380
# Epoch 50/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.8736
# Epoch 50: val_accuracy improved from 0.63957 to 0.64572, saving model to final_model_weights.hdf5
# 358/358 [==============================] - 382s 1s/step - loss: 0.4598 - accuracy: 0.8736 - val_loss: 1.4594 - val_accuracy: 0.6457
# Epoch 51/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4496 - accuracy: 0.8751
# Epoch 51: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 379s 1s/step - loss: 0.4496 - accuracy: 0.8751 - val_loss: 1.5225 - val_accuracy: 0.6313
# Epoch 52/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4445 - accuracy: 0.8777
# Epoch 52: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 381s 1s/step - loss: 0.4445 - accuracy: 0.8777 - val_loss: 1.5201 - val_accuracy: 0.6262
# Epoch 53/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.8826
# Epoch 53: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 382s 1s/step - loss: 0.4412 - accuracy: 0.8826 - val_loss: 1.5824 - val_accuracy: 0.6310
# Epoch 54/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.8848
# Epoch 54: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 384s 1s/step - loss: 0.4401 - accuracy: 0.8848 - val_loss: 1.5718 - val_accuracy: 0.6285
# Epoch 55/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8841
# Epoch 55: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 387s 1s/step - loss: 0.4378 - accuracy: 0.8841 - val_loss: 1.5484 - val_accuracy: 0.6371
# Epoch 56/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.8880
# Epoch 56: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 380s 1s/step - loss: 0.4269 - accuracy: 0.8880 - val_loss: 1.5592 - val_accuracy: 0.6387
# Epoch 57/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.8930
# Epoch 57: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 381s 1s/step - loss: 0.4155 - accuracy: 0.8930 - val_loss: 1.6033 - val_accuracy: 0.6343
# Epoch 58/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8920
# Epoch 58: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 380s 1s/step - loss: 0.4205 - accuracy: 0.8920 - val_loss: 1.5951 - val_accuracy: 0.6331
# Epoch 59/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4172 - accuracy: 0.8948
# Epoch 59: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 383s 1s/step - loss: 0.4172 - accuracy: 0.8948 - val_loss: 1.6145 - val_accuracy: 0.6352
# Epoch 60/100
# 358/358 [==============================] - ETA: 0s - loss: 0.4187 - accuracy: 0.8952Restoring model weights from the end of the best epoch: 50.
#
# Epoch 60: val_accuracy did not improve from 0.64572
# 358/358 [==============================] - 391s 1s/step - loss: 0.4187 - accuracy: 0.8952 - val_loss: 1.5691 - val_accuracy: 0.6336
# Epoch 60: early stopping

# %%
model_yaml = model.to_json()
with open("model.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
    
model.save("model.h5")

# %%
print(f"Test accuracy = {model.evaluate(test_data ,batch_size=test_data.batch_size,steps=test_data.n // test_data.batch_size)[1]*100}%")
# Out:
# 112/112 [==============================] - 71s 642ms/step - loss: 1.4305 - accuracy: 0.6348
# Test accuracy = 63.4765625%
